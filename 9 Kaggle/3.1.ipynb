# %% [markdown]
# Data sourced from https://www.kaggle.com/datasets/ivansabik/mexican-federal-government-salaries/
#
# ### How can we detect problems with the data?
#
# -   Sample the data using `.head()` and look for problems
# -   Use `.dtype` to verify datatypes
# -   Use `.value_counts()` to find any non-NaN default values or common preceeding whitespace in values
# -   Use `.duplicated()` to check that there are no duplicate values

# %%
import pandas

df = pandas.read_csv("./3.0.csv")
df.head()
# Out:
#   entidadfederativa                                     sujetoobligado  \
# 0           Hidalgo                                           Jaltocán
# 1  Ciudad de México                                Secretaría de Salud
# 2  Ciudad de México                  Secretaría de Seguridad Ciudadana
# 3        Federación  Autoridad Educativa Federal en la Ciudad de Mé...
# 4    Aguascalientes                       MUNICIPIO DE RINCÓN DE ROMOS
#
#                            nombre                       denominacion  \
# 0      Adolfo Hernandez Hernandez                          Fontanero
# 1   ARELY SAMANTA CLEOFAS VELASCO         AUXILIAR DE ENFERMERIA "A"
# 2  MELODY OLIMPIC GONZALEZ MONTES                    POLICIA PRIMERO
# 3            ANGEL ALLENDE PULIDO  APOYO Y ASISTENCIA A LA EDUCACION
# 4          Yolanda Reyes Gonzalez                           DIRECTOR
#
#    montoneto                              cargo  \
# 0    4000.00                          Fontanero
# 1   12177.86         AUXILIAR DE ENFERMERIA "A"
# 2   11652.00                    POLICIA PRIMERO
# 3   10180.57  APOYO Y ASISTENCIA A LA EDUCACION
# 4   17004.40                           DIRECTOR
#
#                                                 area  montobruto  \
# 0                                     OBRAS PUBLICAS     4254.00
# 1                               H.G. ENRIQUE CABRERA    16092.00
# 2                SUBSECRETARIA DE OPERACION POLICIAL    16030.00
# 3  DIRECCIÓN GENERAL DE OPERACIONES DE SERVICIOS ...     2910.65
# 4                                      ACCION CIVICA     6188.40
#
#    idInformacion periodoreportainicio periodoreportafin
# 0       16311845           01/01/2018        30/06/2018
# 1       16480190           01/01/2018        31/03/2018
# 2       17599078           01/01/2020        31/03/2020
# 3        6514612           01/07/2018        31/12/2018
# 4       11927166           01/07/2019        31/12/2019

# %%
df.dtypes
# Out:
# entidadfederativa        object
# sujetoobligado           object
# nombre                   object
# denominacion             object
# montoneto               float64
# cargo                    object
# area                     object
# montobruto              float64
# idInformacion             int64
# periodoreportainicio     object
# periodoreportafin        object
# dtype: object

# %%
df.size
# Out:
# 21759705

# %%
for column in df.columns:
    print(f"---- {column} ----")
    print(df[column].value_counts().head(5))
    if df[column].dtype == object:
        print("-- First characters --")
        print(df[column].str[0].value_counts().head(5))
# Out:
# ---- entidadfederativa ----
# Federación          676723
# Ciudad de México    312648
# Guerrero            141018
# Aguascalientes      128410
# Chiapas             108193
# Name: entidadfederativa, dtype: int64
# -- First characters --
# F    676723
# C    604055
# G    179415
# A    128410
# B    124552
# Name: entidadfederativa, dtype: int64
# ---- sujetoobligado ----
# Instituto Mexicano del Seguro Social (IMSS)                   126635
# Secretaría de Educación Guerrero (SEG)                        110388
# INSTITUTO DE EDUCACIÓN DE AGUASCALIENTES                      106848
# Autoridad Educativa Federal en la Ciudad de México (AEFCM)     96230
# Secretaría de Educación                                        78678
# Name: sujetoobligado, dtype: int64
# -- First characters --
# S    696701
# I    401283
# A    248081
# C    212808
# P    156358
# Name: sujetoobligado, dtype: int64
# ---- nombre ----
# RESERVADO RESERVADO RESERVADO                                                                                                                                                  14136
# ND ND ND                                                                                                                                                                        2736
# Clasificado nombre del personal adscrito. Ver Nota Clasificado Primer Apellido del personal adscrito. Ver Nota Clasificado Segundo Apellido del personal adscrito. Ver Nota     2724
# Eliminado.Nombre de servidor público Eliminado.Nombre de servidor público Eliminado.Nombre de servidor público                                                                  1857
# RESERVADA RESERVADA RESERVADA                                                                                                                                                   1720
# Name: nombre, dtype: int64
# -- First characters --
# M    297546
# J    267904
# A    213016
# R    144198
# E    120612
# Name: nombre, dtype: int64
# ---- denominacion ----
# Docente                                   91997
# Ver nota                                  32332
# na                                        32055
# MAESTRO DE GRUPO DE PRIMARIA, FORANEO.    28690
# POLICIA SEGUNDO                           28137
# Name: denominacion, dtype: int64
# -- First characters --
# A    372250
# P    295687
# D    197783
# M    172191
# O    132324
# Name: denominacion, dtype: int64
# ---- montoneto ----
# 0.00        51562
# 30215.25    11622
# 16104.31    10444
# 13530.86     9549
# 20189.86     9476
# Name: montoneto, dtype: int64
# ---- cargo ----
# Docente                                   91997
# Ver nota                                  32332
# na                                        32055
# MAESTRO DE GRUPO DE PRIMARIA, FORANEO.    28690
# POLICIA SEGUNDO                           28137
# Name: cargo, dtype: int64
# -- First characters --
# A    372250
# P    295687
# D    197783
# M    172191
# O    132324
# Name: cargo, dtype: int64
# ---- area ----
# SUBSECRETARIA DE OPERACION POLICIAL                  15959
# UNIDAD DE COORDINACIÓN DE DELEGACIONES               15524
# SACMEX                                               13977
# DIRECCIÓN GENERAL DE EDUCACIÓN SECUNDARIA TÉCNICA    13483
# SUBSECRETARIA DE EDUCACION BASICA                    10051
# Name: area, dtype: int64
# -- First characters --
# D    415903
# S    340040
# C    208572
# J    121026
# E     84732
# Name: area, dtype: int64
# ---- montobruto ----
# 0.00        31424
# 33132.92    11622
# 16871.48    10444
# 26673.21    10117
# 14109.52     9550
# Name: montobruto, dtype: int64
# ---- idInformacion ----
# 8390657     1
# 12229135    1
# 52715984    1
# 40143309    1
# 40151497    1
# Name: idInformacion, dtype: int64
# ---- periodoreportainicio ----
# 01/01/2018    316811
# 01/01/2019    273428
# 01/07/2018    252650
# 01/07/2019    202049
# 01/01/2020    153871
# Name: periodoreportainicio, dtype: int64
# -- First characters --
# 0    1935603
# 1      32896
# 2       7394
# 3       2262
# Name: periodoreportainicio, dtype: int64
# ---- periodoreportafin ----
# 31/12/2018    313587
# 30/06/2018    284571
# 30/06/2019    261187
# 31/12/2019    205199
# 30/06/2020    107182
# Name: periodoreportafin, dtype: int64
# -- First characters --
# 3    1888085
# 2      43125
# 1      36258
# 0      10687
# Name: periodoreportafin, dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [entidadfederativa, sujetoobligado, nombre, denominacion, montoneto, cargo, area, montobruto, idInformacion, periodoreportainicio, periodoreportafin]
# Index: []

# %% [markdown]
# | What problems should we worry about?                         | What can we do about these problems?   |
# | ------------------------------------------------------------ | -------------------------------------- |
# | All field values are in Spanish and lowercase without spaces | Rename all to use English _snake_case_ |
# | `idInformation` isn't useful                                 | Drop it                                |
# | `periodoreportafin` and `periodoreportainicio` aren't dates  | Convert them                           |
# | Many unavailable `nombre` values should be normalized        | Replace                                |
# | `"Ver nota"` and `"na"` as default values for `denominacion` | Replace with `NaN`                     |
# | `cargo` and `denominacion` appear to be identical            | Drop one                               |
